# %%
# !pip install moviepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting moviepy
#   Using cached moviepy-2.1.2-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from moviepy) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from moviepy) (2.36.1)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy)
#   Using cached imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: numpy>=1.25.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from moviepy) (2.0.2)
# Collecting proglog<=1.0.0 (from moviepy)
#   Using cached proglog-0.1.11-py3-none-any.whl.metadata (794 bytes)
# Collecting python-dotenv>=0.10 (from moviepy)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting pillow<11.0,>=9.2.0 (from moviepy)
#   Downloading pillow-10.4.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from proglog<=1.0.0->moviepy) (4.66.5)
# Using cached moviepy-2.1.2-py3-none-any.whl (126 kB)
# Using cached imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl (21.1 MB)
# Downloading pillow-10.4.0-cp39-cp39-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 24.8 MB/s eta 0:00:00
# Using cached proglog-0.1.11-py3-none-any.whl (7.8 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, proglog, pillow, imageio_ffmpeg, moviepy
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.0.0
#     Uninstalling pillow-11.0.0:
#       Successfully uninstalled pillow-11.0.0
# Successfully installed imageio_ffmpeg-0.6.0 moviepy-2.1.2 pillow-10.4.0 proglog-0.1.11 python-dotenv-1.1.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
# !pip install gymnasium torch tensorboard opencv-python imageio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gymnasium in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (1.1.1)
# Requirement already satisfied: torch in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (2.7.0)
# Requirement already satisfied: tensorboard in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (2.18.0)
# Requirement already satisfied: opencv-python in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (4.11.0.86)
# Requirement already satisfied: imageio in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (2.36.1)
# Requirement already satisfied: numpy>=1.21.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from gymnasium) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: filelock in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from torch) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (3.7)
# Requirement already satisfied: packaging in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (24.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (5.29.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard) (58.0.4)
# Requirement already satisfied: six>1.9 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard) (1.15.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: pillow>=8.3.2 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from imageio) (10.4.0)
# Requirement already satisfied: zipp>=3.20 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.20.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
# !pip install swig
# !pip install gymnasium[box2d]
# !pip install gymnasium torch tensorboard moviepy opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting swig
#   Using cached swig-4.3.1-py3-none-macosx_10_9_universal2.whl.metadata (3.5 kB)
# Using cached swig-4.3.1-py3-none-macosx_10_9_universal2.whl (2.6 MB)
# Installing collected packages: swig
# Successfully installed swig-4.3.1
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# zsh:1: no matches found: gymnasium[box2d]
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gymnasium
#   Using cached gymnasium-1.1.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting torch
#   Downloading torch-2.7.0-cp39-none-macosx_11_0_arm64.whl.metadata (29 kB)
# Requirement already satisfied: tensorboard in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (2.18.0)
# Requirement already satisfied: moviepy in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (2.1.2)
# Collecting opencv-python
#   Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from gymnasium) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting filelock (from torch)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from torch) (3.1.6)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: absl-py>=0.4 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (3.7)
# Requirement already satisfied: packaging in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (24.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (5.29.1)
# Requirement already satisfied: setuptools>=41.0.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard) (58.0.4)
# Requirement already satisfied: six>1.9 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorboard) (1.15.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from moviepy) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from moviepy) (2.36.1)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from moviepy) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from moviepy) (0.1.11)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from moviepy) (1.1.0)
# Requirement already satisfied: pillow<11.0,>=9.2.0 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from moviepy) (10.4.0)
# Requirement already satisfied: zipp>=3.20 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.20.2)
# Requirement already satisfied: tqdm in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from proglog<=1.0.0->moviepy) (4.66.5)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/watersterminal/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Using cached gymnasium-1.1.1-py3-none-any.whl (965 kB)
# Downloading torch-2.7.0-cp39-none-macosx_11_0_arm64.whl (68.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 MB 19.7 MB/s eta 0:00:0000:0100:01
# Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 31.4 MB/s eta 0:00:00
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, farama-notifications, sympy, opencv-python, fsspec, filelock, torch, gymnasium
# Successfully installed farama-notifications-0.0.4 filelock-3.18.0 fsspec-2025.3.2 gymnasium-1.1.1 mpmath-1.3.0 opencv-python-4.11.0.86 sympy-1.13.3 torch-2.7.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
import gymnasium as gym
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
import os
import uuid
import imageio
import cv2

# =========================== CONFIG ===========================
GAMMA = 0.99
LR = 1e-3
BATCH_SIZE = 64
BUFFER_SIZE = 100_000
MIN_REPLAY_SIZE = 1_000
TARGET_UPDATE_FREQ = 1000
EPSILON_START = 1.0
EPSILON_END = 0.01
EPSILON_DECAY = 0.9995
NUM_EPISODES = 1000
RENDER_EVERY = 25
VIDEO_DIR = "videos"

os.makedirs(VIDEO_DIR, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
writer = SummaryWriter(f"runs/DQN_LunarLander_{datetime.now().strftime('%Y%m%d_%H%M%S')}")

# ========================= ENV SETUP ===========================
def make_env(record=False):
    return gym.make("LunarLander-v3", render_mode="rgb_array" if record else None)

env = make_env()
obs_dim = env.observation_space.shape[0]
n_actions = env.action_space.n

# ========================= Q-NETWORK ===========================
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128), nn.ReLU(),
            nn.Linear(128, 128), nn.ReLU(),
            nn.Linear(128, output_dim)
        )

    def forward(self, x):
        return self.net(x)

policy_net = DQN(obs_dim, n_actions).to(device)
target_net = DQN(obs_dim, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()
optimizer = optim.Adam(policy_net.parameters(), lr=LR)
replay_buffer = deque(maxlen=BUFFER_SIZE)

# ===================== INITIAL BUFFER ==========================
obs, _ = env.reset()
for _ in range(MIN_REPLAY_SIZE):
    action = env.action_space.sample()
    next_obs, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    replay_buffer.append((obs, action, reward, next_obs, done))
    obs = next_obs if not done else env.reset()[0]

# ====================== VIDEO UTILS ============================
def annotate_frame(frame, score, epoch, landed=False):
    img = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
    font = cv2.FONT_HERSHEY_SIMPLEX
    color = (255, 255, 255)
    cv2.putText(img, f"Score: {score:.1f}", (10, 30), font, 0.8, color, 2)
    cv2.putText(img, f"Epoch: {epoch}", (10, 60), font, 0.8, color, 2)
    if landed:
        cv2.putText(img, "LANDED!", (200, 200), font, 1.5, (0, 255, 0), 4)
        cv2.circle(img, (300, 150), 30, (0, 255, 0), -1)
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

def save_gif(frames, episode):
    uid = uuid.uuid4().hex[:6]
    filename = os.path.join(VIDEO_DIR, f"episode_{episode}_{uid}.gif")
    imageio.mimsave(filename, frames, fps=30)
    print(f"[\u2713] Saved video: {filename}")

# ====================== TRAINING LOOP ==========================
epsilon = EPSILON_START
step_count = 0

for episode in range(1, NUM_EPISODES + 1):
    record_video = episode % RENDER_EVERY == 0 or episode == NUM_EPISODES
    env.close()
    env = make_env(record=record_video)
    obs, _ = env.reset()
    total_reward = 0
    done = False
    frames = []

    while not done:
        if random.random() < epsilon:
            action = env.action_space.sample()
        else:
            with torch.no_grad():
                obs_tensor = torch.tensor(obs, dtype=torch.float32, device=device).unsqueeze(0)
                action = torch.argmax(policy_net(obs_tensor)).item()

        next_obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        replay_buffer.append((obs, action, reward, next_obs, done))
        obs = next_obs
        total_reward += reward
        step_count += 1

        if record_video:
            raw_frame = env.render()
            annotated = annotate_frame(raw_frame, total_reward, episode)
            frames.append(annotated)

        if len(replay_buffer) >= BATCH_SIZE:
            batch = random.sample(replay_buffer, BATCH_SIZE)
            obs_batch, act_batch, rew_batch, next_obs_batch, done_batch = zip(*batch)

            obs_tensor = torch.tensor(obs_batch, dtype=torch.float32, device=device)
            act_tensor = torch.tensor(act_batch, dtype=torch.int64, device=device).unsqueeze(1)
            rew_tensor = torch.tensor(rew_batch, dtype=torch.float32, device=device).unsqueeze(1)
            next_obs_tensor = torch.tensor(next_obs_batch, dtype=torch.float32, device=device)
            done_tensor = torch.tensor(done_batch, dtype=torch.float32, device=device).unsqueeze(1)

            with torch.no_grad():
                max_next_q = target_net(next_obs_tensor).max(1, keepdim=True)[0]
                target_q = rew_tensor + GAMMA * max_next_q * (1 - done_tensor)

            current_q = policy_net(obs_tensor).gather(1, act_tensor)
            loss = nn.MSELoss()(current_q, target_q)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            writer.add_scalar("Loss", loss.item(), global_step=step_count)

        if step_count % TARGET_UPDATE_FREQ == 0:
            target_net.load_state_dict(policy_net.state_dict())

    epsilon = max(EPSILON_END, epsilon * EPSILON_DECAY)
    writer.add_scalar("Episode Reward", total_reward, global_step=episode)
    print(f"Ep {episode} | Reward: {total_reward:.2f} | Epsilon: {epsilon:.3f}")

    if record_video:
        landed = total_reward > 200  # success threshold
        if landed:
            for _ in range(15):
                frames.append(annotate_frame(frames[-1], total_reward, episode, landed=True))
        save_gif(frames, episode)

env.close()
writer.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/gymnasium/envs/box2d/bipedal_walker.py:15
#      14 try:
# ---> 15     import Box2D
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)
#      22         revoluteJointDef,
#      23     )
#
# ModuleNotFoundError: No module named 'Box2D'
#
# The above exception was the direct cause of the following exception:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[7], line 37
#      34 def make_env(record=False):
#      35     return gym.make("LunarLander-v3", render_mode="rgb_array" if record else None)
# ---> 37 env = make_env()
#      38 obs_dim = env.observation_space.shape[0]
#      39 n_actions = env.action_space.n
#
# Cell In[7], line 35, in make_env(record)
#      34 def make_env(record=False):
# ---> 35     return gym.make("LunarLander-v3", render_mode="rgb_array" if record else None)
#
# File ~/Library/Python/3.9/lib/python/site-packages/gymnasium/envs/registration.py:704, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     701     env_creator = env_spec.entry_point
#     702 else:
#     703     # Assume it's a string
# --> 704     env_creator = load_env_creator(env_spec.entry_point)
#     706 # Determine if to use the rendering
#     707 render_modes: list[str] | None = None
#
# File ~/Library/Python/3.9/lib/python/site-packages/gymnasium/envs/registration.py:551, in load_env_creator(name)
#     542 """Loads an environment with name of style ``"(import path):(environment name)"`` and returns the environment creation function, normally the environment class type.
#     543
#     544 Args:
#    (...)
#     548     The environment constructor for the given environment name.
#     549 """
#     550 mod_name, attr_name = name.split(":")
# --> 551 mod = importlib.import_module(mod_name)
#     552 fn = getattr(mod, attr_name)
#     553 return fn
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:972, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Library/Python/3.9/lib/python/site-packages/gymnasium/envs/box2d/__init__.py:1
# ----> 1 from gymnasium.envs.box2d.bipedal_walker import BipedalWalker, BipedalWalkerHardcore
#       2 from gymnasium.envs.box2d.car_racing import CarRacing
#       3 from gymnasium.envs.box2d.lunar_lander import LunarLander, LunarLanderContinuous
#
# File ~/Library/Python/3.9/lib/python/site-packages/gymnasium/envs/box2d/bipedal_walker.py:25
#      16     from Box2D.b2 import (
#      17         circleShape,
#      18         contactListener,
#    (...)
#      22         revoluteJointDef,
#      23     )
#      24 except ImportError as e:
# ---> 25     raise DependencyNotInstalled(
#      26         'Box2D is not installed, you can install it by run `pip install swig` followed by `pip install "gymnasium[box2d]"`'
#      27     ) from e
#      30 if TYPE_CHECKING:
#      31     import pygame
#
# DependencyNotInstalled: Box2D is not installed, you can install it by run `pip install swig` followed by `pip install "gymnasium[box2d]"`
